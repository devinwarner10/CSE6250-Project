# %% [markdown]
# This cell adds your Google Drive to the folder structure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This cell downloads required modules, sets CUDA machine, and sets the working directory to your Google Drive.

# %%
# Download Modules
# !pip install dill

# Import Required Modules
from google.colab import auth
import torch
import torch.nn.functional as F
import dill
import numpy as np
import torch
import os


# Check cuda
if torch.cuda.is_available():
    torch.cuda.set_device(0)

# Set Working Directory
os.chdir("drive/MyDrive/CSE6250 Project")

# %% [markdown]
# Run 4SDrug as is from the GitHub repo.

# %%
# %run "main_4sdrug.py --batch_size 50 --alpha 0.5 --beta 1.0"
# Out:
# Namespace(device=0, embedding_dim=64, epoch=200, beta=1.0, lr=0.0002, batch_size=50, score_threshold=0.5, alpha=0.5, dataset='MIMIC3')
# num symptom: 1958, num drug: 112
# /content/drive/MyDrive/CSE6250 Project/main_4sdrug.py:100: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   torch.tensor(pklSet.drug_multihots).to(device), args.embedding_dim).to(device)
# total number of parameters:  132545
#   0%|          | 0/200 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]/content/drive/MyDrive/CSE6250 Project/model/radm.py:60: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# ...
